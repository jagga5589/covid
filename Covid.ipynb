# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('C:/Users/jxp422/Desktop/Work/Learn/dataSets/covid/time_series_covid19_confirmed_global.csv')
g_death = df
g_death
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  5/11/20  5/12/20  \
# ...

# %%
g_death.columns[4:]
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '5/11/20', '5/12/20', '5/13/20', '5/14/20', '5/15/20', '5/16/20',
#        '5/17/20', '5/18/20', '5/19/20', '5/20/20'],
#       dtype='object', length=120)

# %%
g_dates = list(g_death.columns[38:])
len(g_dates)
# Out:
# 86

# %%
p_death  = g_death[g_death['Country/Region'] == 'Pakistan']
p_death.iloc[:, 38:]
# Out:
#      2/25/20  2/26/20  2/27/20  2/28/20  2/29/20  3/1/20  3/2/20  3/3/20  \
# 177        0        2        2        2        4       4       4       5
#
#      3/4/20  3/5/20  ...  5/11/20  5/12/20  5/13/20  5/14/20  5/15/20  \
# 177       5       5  ...    32081    34336    35298    35788    38799
#
#      5/16/20  5/17/20  5/18/20  5/19/20  5/20/20
# 177    38799    40151    42125    43966    45898
#
# [1 rows x 86 columns]

# %%
i_death  = g_death[g_death['Country/Region'] == 'India']
p_death.iloc[:, 38:]
# Out:
#      2/25/20  2/26/20  2/27/20  2/28/20  2/29/20  3/1/20  3/2/20  3/3/20  \
# 177        0        2        2        2        4       4       4       5
#
#      3/4/20  3/5/20  ...  5/11/20  5/12/20  5/13/20  5/14/20  5/15/20  \
# 177       5       5  ...    32081    34336    35298    35788    38799
#
#      5/16/20  5/17/20  5/18/20  5/19/20  5/20/20
# 177    38799    40151    42125    43966    45898
#
# [1 rows x 86 columns]

# %%
x = []
y = []
t = []

for dates in g_dates:
    y.append(p_death[dates].to_string(index=False))
    x.append(dates)
    
y = pd.to_numeric(y)
t = pd.to_numeric(t)

for i in range(len(y)):
    if i > 0:
        y[i] = y[i] - y[i-1]


p_grid = pd.DataFrame({'Dates':x, 'Deaths':y})
p_grid['Dates'] = p_grid['Dates'].apply(pd.to_datetime)
p_grid
# Out:
#         Dates  Deaths
# 0  2020-02-25       0
# 1  2020-02-26       2
# 2  2020-02-27       0
# 3  2020-02-28       2
# 4  2020-02-29       2
# ..        ...     ...
# 81 2020-05-16   18356
# 82 2020-05-17   21795
# 83 2020-05-18   20330
# 84 2020-05-19   23636
# 85 2020-05-20   22262
#
# [86 rows x 2 columns]

# %%
x = []
y = []
t = []
i_grid

for dates in g_dates:
    y.append(i_death[dates].to_string(index=False))
    x.append(dates)
    
y = pd.to_numeric(y)
t = pd.to_numeric(t)

for i in range(len(y)):
    if i > 0:
        y[i] = y[i] - y[i-1]
i_grid = pd.DataFrame({'Dates':x, 'Deaths':y})
i_grid['Dates'] = i_grid['Dates'].apply(pd.to_datetime)
i_grid
# Out:
#         Dates  Deaths
# 0  2020-02-25       3
# 1  2020-02-26       0
# 2  2020-02-27       3
# 3  2020-02-28       0
# 4  2020-02-29       3
# ..        ...     ...
# 81 2020-05-16   47684
# 82 2020-05-17   48014
# 83 2020-05-18   52314
# 84 2020-05-19   54161
# 85 2020-05-20   57867
#
# [86 rows x 2 columns]

# %%
plt.plot(p_grid.Dates, p_grid.Deaths, label = 'Pakistan', color='Green')
plt.plot(i_grid.Dates, i_grid.Deaths, label = 'India', color = 'Orange')
plt.xlabel('Dates')
plt.ylabel('Deaths')
plt.title('Corona : Deaths rate per day')
plt.legend(loc='upper left')
plt.show()

# %%
i_grid.Deaths = pd.to_numeric(i_grid.Deaths)
i_grid.Deaths

for death in i_grid['Deaths']:
    i_grid['Death']
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#         ...
# 115     90648
# 116     95698
# 117    100328
# 118    106475
# 119    112028
# Name: Deaths, Length: 120, dtype: int64

# %%
num = len(i_grid)
for i in num:
    if i != 0:
        i_grid.Deaths -= i_grid.loc[]
# Out:
# 120
